# %%
import numpy as np
import pandas as pd
from IPython.display import HTML

from collab.foraging.toolkit import (
    animate_predictors,
    dataObject,
    generate_local_windows,
    plot_predictor,
    rescale_to_grid,
)
from collab.foraging.toolkit.communication import (
    _generate_communication_predictor,
    generate_communication_predictor,
)

# %%
# create a test object with random data
num_frames = 8
num_foragers = 4
grid_size = 30
n_nans = int(num_frames * num_foragers / 5)
n_missing = int(num_frames * num_foragers / 5)
gridMin = -1
gridMax = 1

np.random.seed(42)

# generate data in a unit disk
theta = 2 * np.pi * np.random.rand(num_frames * num_foragers)
r = np.random.rand(num_frames * num_foragers)

data = {
    "x": r * np.cos(theta),
    "y": r * np.sin(theta),
    "time": np.tile(np.arange(num_frames), num_foragers),
    "forager": np.concatenate([i * np.ones(num_frames) for i in range(num_foragers)]),
}

foragersDF = pd.DataFrame(data)

foragersDF_scaled = rescale_to_grid(
    foragersDF, size=grid_size, gridMin=gridMin, gridMax=gridMax
)
foragers_object = dataObject(foragersDF_scaled, grid_size=grid_size)

# %%
# get local windows
local_windows_kwargs = {
    "window_size": 10,
    "sampling_fraction": 1,
    "skip_incomplete_frames": False,
}

foragers_object.local_windows_kwargs = local_windows_kwargs

local_windows = generate_local_windows(foragers_object)

foragers_object.local_windows = local_windows

# %%
times = foragers_object.foragersDF["time"].unique()

rewards = []
for time in times:
    rewards.append(
        pd.DataFrame(
            {
                "x": [10, 20, 30],  # "x": [16, 13],
                "y": [5, 5, 5],  # "y": [13, 10],
            }
        )
    )

print(len(rewards))

print(rewards[0])

foragers_object.rewards = rewards
# Out:
# 8
#     x  y
# 0  10  5
# 1  20  5
# 2  30  5

# %%
from collab.foraging.toolkit import filter_by_distance

f = 2
t = 6
L = 15
filter_by_distance(
    foragers_object.foragersDF,
    f=f,
    t=t,
    interaction_length=L,
    interaction_minimal_distance=2,
)
# Out:
# [0.0, 1.0]

# %%
from collab.foraging.toolkit.filtering import constraint_filter_close_to_reward

outcome = filter_by_distance(
    foragers_object.foragersDF,
    f=f,
    t=t,
    interaction_length=L,
    interaction_constraint=constraint_filter_close_to_reward,
    finders_tolerance=14,
    rewards=foragers_object.rewards,
)

print(outcome)
# Out:
# [0]

# %%
interaction_constraint_params = {
    "finders_tolerance": 8,
}

ppr = _generate_communication_predictor(
    foragers=foragers_object.foragers,
    foragersDF=foragers_object.foragersDF,
    rewards=foragers_object.rewards,
    interaction_length=15,
    interaction_constraint_params=interaction_constraint_params,
    predictor_name="pred",
    local_windows=local_windows,
    decay_factor=0.2,
)

# %%
display(ppr)
# Out:
# [[      x   y  distance_to_forager  time  forager  pred
#   135   4  15            10.000000     0        0     0
#   161   5  11             9.848858     0        0     0
#   162   5  12             9.486833     0        0     0
#   163   5  13             9.219544     0        0     0
#   164   5  14             9.055385     0        0     0
#   ..   ..  ..                  ...   ...      ...   ...
#   706  23  16             9.055385     0        0     0
#   707  23  17             9.219544     0        0     0
#   708  23  18             9.486833     0        0     0
#   709  23  19             9.848858     0        0     0
#   735  24  15            10.000000     0        0     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   550  18  10            10.000000     1        0     0
#   576  19   6             9.848858     1        0     0
#   577  19   7             9.486833     1        0     0
#   578  19   8             9.219544     1        0     0
#   579  19   9             9.055385     1        0     0
#   ..   ..  ..                  ...   ...      ...   ...
#   885  29  15             5.099020     1        0     0
#   886  29  16             6.082763     1        0     0
#   887  29  17             7.071068     1        0     0
#   888  29  18             8.062258     1        0     0
#   889  29  19             9.055385     1        0     0
#
#   [188 rows x 6 columns],
#         x  y  distance_to_forager  time  forager  pred
#   90    3  0            10.000000     2        0     0
#   120   4  0             9.000000     2        0     0
#   121   4  1             9.055385     2        0     0
#   122   4  2             9.219544     2        0     0
#   123   4  3             9.486833     2        0     0
#   ..   .. ..                  ...   ...      ...   ...
#   661  22  1             9.055385     2        0     0
#   662  22  2             9.219544     2        0     0
#   663  22  3             9.486833     2        0     0
#   664  22  4             9.848858     2        0     0
#   690  23  0            10.000000     2        0     0
#
#   [169 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   0     0   0             8.602325     3        0     0
#   1     0   1             7.810250     3        0     0
#   2     0   2             7.071068     3        0     0
#   3     0   3             6.403124     3        0     0
#   4     0   4             5.830952     3        0     0
#   ..   ..  ..                  ...   ...      ...   ...
#   428  14   8             9.055385     3        0     0
#   429  14   9             9.219544     3        0     0
#   430  14  10             9.486833     3        0     0
#   431  14  11             9.848858     3        0     0
#   457  15   7            10.000000     3        0     0
#
#   [240 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   228   7  18            10.000000     4        0  0.246136
#   254   8  14             9.848858     4        0  0.512833
#   255   8  15             9.486833     4        0  0.442665
#   256   8  16             9.219544     4        0  0.378238
#   257   8  17             9.055385     4        0  0.320936
#   ..   ..  ..                  ...   ...      ...       ...
#   799  26  19             9.055385     4        0  0.080809
#   800  26  20             9.219544     4        0  0.071680
#   801  26  21             9.486833     4        0  0.063077
#   802  26  22             9.848858     4        0  0.055120
#   828  27  18            10.000000     4        0  0.076088
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   166   5  16            10.000000     5        0     0
#   192   6  12             9.848858     5        0     0
#   193   6  13             9.486833     5        0     0
#   194   6  14             9.219544     5        0     0
#   195   6  15             9.055385     5        0     0
#   ..   ..  ..                  ...   ...      ...   ...
#   737  24  17             9.055385     5        0     0
#   738  24  18             9.219544     5        0     0
#   739  24  19             9.486833     5        0     0
#   740  24  20             9.848858     5        0     0
#   766  25  16            10.000000     5        0     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   438  14  18            10.000000     6        0     0
#   464  15  14             9.848858     6        0     0
#   465  15  15             9.486833     6        0     0
#   466  15  16             9.219544     6        0     0
#   467  15  17             9.055385     6        0     0
#   ..   ..  ..                  ...   ...      ...   ...
#   892  29  22             6.403124     6        0     0
#   893  29  23             7.071068     6        0     0
#   894  29  24             7.810250     6        0     0
#   895  29  25             8.602325     6        0     0
#   896  29  26             9.433981     6        0     0
#
#   [262 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   280   9  10            10.000000     7        0     0
#   306  10   6             9.848858     7        0     0
#   307  10   7             9.486833     7        0     0
#   308  10   8             9.219544     7        0     0
#   309  10   9             9.055385     7        0     0
#   ..   ..  ..                  ...   ...      ...   ...
#   851  28  11             9.055385     7        0     0
#   852  28  12             9.219544     7        0     0
#   853  28  13             9.486833     7        0     0
#   854  28  14             9.848858     7        0     0
#   880  29  10            10.000000     7        0     0
#
#   [317 rows x 6 columns]],
#  [      x   y  distance_to_forager  time  forager  pred
#   103   3  13            10.000000     0        1     0
#   129   4   9             9.848858     0        1     0
#   130   4  10             9.486833     0        1     0
#   131   4  11             9.219544     0        1     0
#   132   4  12             9.055385     0        1     0
#   ..   ..  ..                  ...   ...      ...   ...
#   674  22  14             9.055385     0        1     0
#   675  22  15             9.219544     0        1     0
#   676  22  16             9.486833     0        1     0
#   677  22  17             9.848858     0        1     0
#   703  23  13            10.000000     0        1     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   97    3   7            10.000000     1        1     0
#   123   4   3             9.848858     1        1     0
#   124   4   4             9.486833     1        1     0
#   125   4   5             9.219544     1        1     0
#   126   4   6             9.055385     1        1     0
#   ..   ..  ..                  ...   ...      ...   ...
#   668  22   8             9.055385     1        1     0
#   669  22   9             9.219544     1        1     0
#   670  22  10             9.486833     1        1     0
#   671  22  11             9.848858     1        1     0
#   697  23   7            10.000000     1        1     0
#
#   [294 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   165   5  15            10.000000     2        1     0
#   191   6  11             9.848858     2        1     0
#   192   6  12             9.486833     2        1     0
#   193   6  13             9.219544     2        1     0
#   194   6  14             9.055385     2        1     0
#   ..   ..  ..                  ...   ...      ...   ...
#   736  24  16             9.055385     2        1     0
#   737  24  17             9.219544     2        1     0
#   738  24  18             9.486833     2        1     0
#   739  24  19             9.848858     2        1     0
#   765  25  15            10.000000     2        1     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   552  18  12            10.000000     3        1     0
#   578  19   8             9.848858     3        1     0
#   579  19   9             9.486833     3        1     0
#   580  19  10             9.219544     3        1     0
#   581  19  11             9.055385     3        1     0
#   ..   ..  ..                  ...   ...      ...   ...
#   887  29  17             5.099020     3        1     0
#   888  29  18             6.082763     3        1     0
#   889  29  19             7.071068     3        1     0
#   890  29  20             8.062258     3        1     0
#   891  29  21             9.055385     3        1     0
#
#   [188 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   191   6  11            10.000000     4        1  0.618306
#   217   7   7             9.848858     4        1  0.721835
#   218   7   8             9.486833     4        1  0.723523
#   219   7   9             9.219544     4        1  0.721835
#   220   7  10             9.055385     4        1  0.712324
#   ..   ..  ..                  ...   ...      ...       ...
#   762  25  12             9.055385     4        1  0.051896
#   763  25  13             9.219544     4        1  0.050416
#   764  25  14             9.486833     4        1  0.048409
#   765  25  15             9.848858     4        1  0.045955
#   791  26  11            10.000000     4        1  0.043286
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   234   7  24            10.000000     5        1     0
#   260   8  20             9.848858     5        1     0
#   261   8  21             9.486833     5        1     0
#   262   8  22             9.219544     5        1     0
#   263   8  23             9.055385     5        1     0
#   ..   ..  ..                  ...   ...      ...   ...
#   805  26  25             9.055385     5        1     0
#   806  26  26             9.219544     5        1     0
#   807  26  27             9.486833     5        1     0
#   808  26  28             9.848858     5        1     0
#   834  27  24            10.000000     5        1     0
#
#   [262 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   199   6  19            10.000000     6        1     0
#   225   7  15             9.848858     6        1     0
#   226   7  16             9.486833     6        1     0
#   227   7  17             9.219544     6        1     0
#   228   7  18             9.055385     6        1     0
#   ..   ..  ..                  ...   ...      ...   ...
#   770  25  20             9.055385     6        1     0
#   771  25  21             9.219544     6        1     0
#   772  25  22             9.486833     6        1     0
#   773  25  23             9.848858     6        1     0
#   799  26  19            10.000000     6        1     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   262   8  22            10.000000     7        1  0.060292
#   288   9  18             9.848858     7        1  0.120750
#   289   9  19             9.486833     7        1  0.106085
#   290   9  20             9.219544     7        1  0.092438
#   291   9  21             9.055385     7        1  0.079978
#   ..   ..  ..                  ...   ...      ...       ...
#   833  27  23             9.055385     7        1  0.073855
#   834  27  24             9.219544     7        1  0.062182
#   835  27  25             9.486833     7        1  0.052194
#   836  27  26             9.848858     7        1  0.043696
#   862  28  22            10.000000     7        1  0.077864
#
#   [294 rows x 6 columns]],
#  [      x   y  distance_to_forager  time  forager  pred
#   82    2  22            10.000000     0        2     0
#   108   3  18             9.848858     0        2     0
#   109   3  19             9.486833     0        2     0
#   110   3  20             9.219544     0        2     0
#   111   3  21             9.055385     0        2     0
#   ..   ..  ..                  ...   ...      ...   ...
#   653  21  23             9.055385     0        2     0
#   654  21  24             9.219544     0        2     0
#   655  21  25             9.486833     0        2     0
#   656  21  26             9.848858     0        2     0
#   682  22  22            10.000000     0        2     0
#
#   [294 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   74    2  14            10.000000     1        2  0.073705
#   100   3  10             9.848858     1        2  0.123927
#   101   3  11             9.486833     1        2  0.116012
#   102   3  12             9.219544     1        2  0.106878
#   103   3  13             9.055385     1        2  0.097064
#   ..   ..  ..                  ...   ...      ...       ...
#   645  21  15             9.055385     1        2  0.104065
#   646  21  16             9.219544     1        2  0.089966
#   647  21  17             9.486833     1        2  0.077208
#   648  21  18             9.848858     1        2  0.065855
#   674  22  14            10.000000     1        2  0.102248
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   12    0  12             9.055385     2        2     0
#   13    0  13             8.062258     2        2     0
#   14    0  14             7.071068     2        2     0
#   15    0  15             6.082763     2        2     0
#   16    0  16             5.099020     2        2     0
#   ..   ..  ..                  ...   ...      ...   ...
#   322  10  22             9.055385     2        2     0
#   323  10  23             9.219544     2        2     0
#   324  10  24             9.486833     2        2     0
#   325  10  25             9.848858     2        2     0
#   351  11  21            10.000000     2        2     0
#
#   [181 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   86    2  26            10.000000     3        2     0
#   112   3  22             9.848858     3        2     0
#   113   3  23             9.486833     3        2     0
#   114   3  24             9.219544     3        2     0
#   115   3  25             9.055385     3        2     0
#   ..   ..  ..                  ...   ...      ...   ...
#   656  21  26             9.000000     3        2     0
#   657  21  27             9.055385     3        2     0
#   658  21  28             9.219544     3        2     0
#   659  21  29             9.486833     3        2     0
#   686  22  26            10.000000     3        2     0
#
#   [226 rows x 6 columns],
#         x  y  distance_to_forager  time  forager      pred
#   0     0  0             6.403124     4        2  0.055120
#   1     0  1             5.656854     4        2  0.063077
#   2     0  2             5.000000     4        2  0.071680
#   3     0  3             4.472136     4        2  0.080809
#   4     0  4             4.123106     4        2  0.090271
#   ..   .. ..                  ...   ...      ...       ...
#   396  13  6             9.055385     4        2  0.478870
#   397  13  7             9.219544     4        2  0.565449
#   398  13  8             9.486833     4        2  0.657926
#   399  13  9             9.848858     4        2  0.747332
#   425  14  5            10.000000     4        2  0.398608
#
#   [199 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   415  13  25            10.000000     5        2     0
#   441  14  21             9.848858     5        2     0
#   442  14  22             9.486833     5        2     0
#   443  14  23             9.219544     5        2     0
#   444  14  24             9.055385     5        2     0
#   ..   ..  ..                  ...   ...      ...   ...
#   895  29  25             6.000000     5        2     0
#   896  29  26             6.082763     5        2     0
#   897  29  27             6.324555     5        2     0
#   898  29  28             6.708204     5        2     0
#   899  29  29             7.211103     5        2     0
#
#   [212 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   83    2  23            10.000000     6        2     0
#   109   3  19             9.848858     6        2     0
#   110   3  20             9.486833     6        2     0
#   111   3  21             9.219544     6        2     0
#   112   3  22             9.055385     6        2     0
#   ..   ..  ..                  ...   ...      ...   ...
#   654  21  24             9.055385     6        2     0
#   655  21  25             9.219544     6        2     0
#   656  21  26             9.486833     6        2     0
#   657  21  27             9.848858     6        2     0
#   683  22  23            10.000000     6        2     0
#
#   [279 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   17    0  17             9.433981     7        2     0
#   18    0  18             8.602325     7        2     0
#   19    0  19             7.810250     7        2     0
#   20    0  20             7.071068     7        2     0
#   21    0  21             6.403124     7        2     0
#   ..   ..  ..                  ...   ...      ...   ...
#   446  14  26             9.055385     7        2     0
#   447  14  27             9.219544     7        2     0
#   448  14  28             9.486833     7        2     0
#   449  14  29             9.848858     7        2     0
#   475  15  25            10.000000     7        2     0
#
#   [199 rows x 6 columns]],
#  [      x   y  distance_to_forager  time  forager  pred
#   105   3  15            10.000000     0        3     0
#   131   4  11             9.848858     0        3     0
#   132   4  12             9.486833     0        3     0
#   133   4  13             9.219544     0        3     0
#   134   4  14             9.055385     0        3     0
#   ..   ..  ..                  ...   ...      ...   ...
#   676  22  16             9.055385     0        3     0
#   677  22  17             9.219544     0        3     0
#   678  22  18             9.486833     0        3     0
#   679  22  19             9.848858     0        3     0
#   705  23  15            10.000000     0        3     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   162   5  12            10.000000     1        3  0.154201
#   188   6   8             9.848858     1        3  0.243738
#   189   6   9             9.486833     1        3  0.234387
#   190   6  10             9.219544     1        3  0.219980
#   191   6  11             9.055385     1        3  0.202137
#   ..   ..  ..                  ...   ...      ...       ...
#   733  24  13             9.055385     1        3  0.429332
#   734  24  14             9.219544     1        3  0.378537
#   735  24  15             9.486833     1        3  0.328316
#   736  24  16             9.848858     1        3  0.281475
#   762  25  12            10.000000     1        3  0.535369
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   165   5  15            10.000000     2        3     0
#   191   6  11             9.848858     2        3     0
#   192   6  12             9.486833     2        3     0
#   193   6  13             9.219544     2        3     0
#   194   6  14             9.055385     2        3     0
#   ..   ..  ..                  ...   ...      ...   ...
#   736  24  16             9.055385     2        3     0
#   737  24  17             9.219544     2        3     0
#   738  24  18             9.486833     2        3     0
#   739  24  19             9.848858     2        3     0
#   765  25  15            10.000000     2        3     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   14    0  14            10.000000     3        3  0.178983
#   40    1  10             9.848858     3        3  0.367879
#   41    1  11             9.486833     3        3  0.322591
#   42    1  12             9.219544     3        3  0.277864
#   43    1  13             9.055385     3        3  0.236402
#   ..   ..  ..                  ...   ...      ...       ...
#   585  19  15             9.055385     3        3  0.039760
#   586  19  16             9.219544     3        3  0.035841
#   587  19  17             9.486833     3        3  0.032035
#   588  19  18             9.848858     3        3  0.028413
#   614  20  14            10.000000     3        3  0.036495
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   11    0  11            10.000000     4        3  0.259435
#   37    1   7             9.848858     4        3  0.497075
#   38    1   8             9.486833     4        3  0.444578
#   39    1   9             9.219544     4        3  0.389729
#   40    1  10             9.055385     4        3  0.337916
#   ..   ..  ..                  ...   ...      ...       ...
#   582  19  12             9.055385     4        3  0.531461
#   583  19  13             9.219544     4        3  0.486349
#   584  19  14             9.486833     4        3  0.428970
#   585  19  15             9.848858     4        3  0.369782
#   611  20  11            10.000000     4        3  0.451280
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   256   8  16            10.000000     5        3     0
#   282   9  12             9.848858     5        3     0
#   283   9  13             9.486833     5        3     0
#   284   9  14             9.219544     5        3     0
#   285   9  15             9.055385     5        3     0
#   ..   ..  ..                  ...   ...      ...   ...
#   827  27  17             9.055385     5        3     0
#   828  27  18             9.219544     5        3     0
#   829  27  19             9.486833     5        3     0
#   830  27  20             9.848858     5        3     0
#   856  28  16            10.000000     5        3     0
#
#   [317 rows x 6 columns],
#         x   y  distance_to_forager  time  forager  pred
#   0     0   0             8.602325     6        3     0
#   1     0   1             7.810250     6        3     0
#   2     0   2             7.071068     6        3     0
#   3     0   3             6.403124     6        3     0
#   4     0   4             5.830952     6        3     0
#   ..   ..  ..                  ...   ...      ...   ...
#   428  14   8             9.055385     6        3     0
#   429  14   9             9.219544     6        3     0
#   430  14  10             9.486833     6        3     0
#   431  14  11             9.848858     6        3     0
#   457  15   7            10.000000     6        3     0
#
#   [240 rows x 6 columns],
#         x   y  distance_to_forager  time  forager      pred
#   229   7  19            10.000000     7        3  0.049787
#   255   8  15             9.848858     7        3  0.089224
#   256   8  16             9.486833     7        3  0.081595
#   257   8  17             9.219544     7        3  0.073705
#   258   8  18             9.055385     7        3  0.065855
#   ..   ..  ..                  ...   ...      ...       ...
#   800  26  20             9.055385     7        3  0.087047
#   801  26  21             9.219544     7        3  0.073705
#   802  26  22             9.486833     7        3  0.062132
#   803  26  23             9.848858     7        3  0.052185
#   829  27  19            10.000000     7        3  0.089966
#
#   [317 rows x 6 columns]]]

# %%
plot_predictor(
    foragers_object.foragers,
    ppr,
    "pred",
    forager_position_indices=[0, 1, 2, 3],
    forager_predictor_indices=[1],
    time=range(num_frames),
    grid_size=grid_size,
    size_multiplier=10,
    random_state=99,
)

# %%
predictor_kwargs = {
    "food": {
        "decay_factor": 0.5,
    },
    "communication": {
        "interaction_length": 15,
        "interaction_constraint_params": interaction_constraint_params,
    },
}

foragers_object.predictor_kwargs = predictor_kwargs

# %%
ani = animate_predictors(
    foragers_object.foragersDF,
    ppr,
    predictor_name="pred",
    forager_position_indices=[0, 2, 3],
    forager_predictor_indices=[1],
    grid_size=grid_size,
    random_state=10,
    size_multiplier=10,
)
HTML(ani.to_jshtml())
# Out:
# 2024-10-28 12:53:39,844 - Animation.save using <class 'matplotlib.animation.HTMLWriter'>
# 8
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb2397083b3504296b4f4beb874b9f444">
#   <div class="anim-controls">
#     <input id="_anim_sliderb2397083b3504296b4f4beb874b9f444" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb2397083b3504296b4f4beb874b9f444.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animb2397083b3504296b4f4beb874b9f444.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animb2397083b3504296b4f4beb874b9f444.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animb2397083b3504296b4f4beb874b9f444.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animb2397083b3504296b4f4beb874b9f444.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animb2397083b3504296b4f4beb874b9f444.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animb2397083b3504296b4f4beb874b9f444.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animb2397083b3504296b4f4beb874b9f444.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animb2397083b3504296b4f4beb874b9f444.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animb2397083b3504296b4f4beb874b9f444.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectb2397083b3504296b4f4beb874b9f444"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b2397083b3504296b4f4beb874b9f444"
#              >
#       <label for="_anim_radio1_b2397083b3504296b4f4beb874b9f444">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b2397083b3504296b4f4beb874b9f444"
#              checked>
#       <label for="_anim_radio2_b2397083b3504296b4f4beb874b9f444">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b2397083b3504296b4f4beb874b9f444"
#              >
#       <label for="_anim_radio3_b2397083b3504296b4f4beb874b9f444">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb2397083b3504296b4f4beb874b9f444";
#     var slider_id = "_anim_sliderb2397083b3504296b4f4beb874b9f444";
#     var loop_select_id = "_anim_loop_selectb2397083b3504296b4f4beb874b9f444";
#     var frames = new Array(8);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8hTgPZAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAJpUlEQV

# %%
communication = generate_communication_predictor(
    foragers_object,
    predictor_name="communication",
)

ani = animate_predictors(
    foragers_object.foragersDF,
    communication,
    predictor_name="communication",
    forager_position_indices=[0, 1],
    forager_predictor_indices=[0, 1],
    grid_size=grid_size,
    random_state=10,
    size_multiplier=10,
)
HTML(ani.to_jshtml())
# Out:
# 2024-10-28 12:53:40,397 - Animation.save using <class 'matplotlib.animation.HTMLWriter'>
# 8
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img87f5f353d08145a68b4f57c5ab7d1da9">
#   <div class="anim-controls">
#     <input id="_anim_slider87f5f353d08145a68b4f57c5ab7d1da9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim87f5f353d08145a68b4f57c5ab7d1da9.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim87f5f353d08145a68b4f57c5ab7d1da9.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select87f5f353d08145a68b4f57c5ab7d1da9"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_87f5f353d08145a68b4f57c5ab7d1da9"
#              >
#       <label for="_anim_radio1_87f5f353d08145a68b4f57c5ab7d1da9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_87f5f353d08145a68b4f57c5ab7d1da9"
#              checked>
#       <label for="_anim_radio2_87f5f353d08145a68b4f57c5ab7d1da9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_87f5f353d08145a68b4f57c5ab7d1da9"
#              >
#       <label for="_anim_radio3_87f5f353d08145a68b4f57c5ab7d1da9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img87f5f353d08145a68b4f57c5ab7d1da9";
#     var slider_id = "_anim_slider87f5f353d08145a68b4f57c5ab7d1da9";
#     var loop_select_id = "_anim_loop_select87f5f353d08145a68b4f57c5ab7d1da9";
#     var frames = new Array(8);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8hTgPZAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAJbklEQV
