# %%
import sys
sys.path.insert(0, "..")

import random
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import pyro
import foraging_toolkit as ft
import torch.nn.functional as F
import pyro.distributions as dist
import pyro.optim as optim
from pyro.nn import PyroModule
from pyro.infer.autoguide import AutoNormal, AutoDiagonalNormal, AutoMultivariateNormal, init_to_mean, init_to_value
from pyro.contrib.autoguide import AutoLaplaceApproximation
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam
from pyro.infer import Predictive
from pyro.infer import MCMC, NUTS

import os
import logging
logging.basicConfig(format='%(message)s', level=logging.INFO)
smoke_test = ('CI' in os.environ)


import foraging_toolkit as ft

# %%
random.seed(22)
np.random.seed(22)
hungry_sim = ft.Birds(grid_size= 150, num_birds= 3, num_frames= 10, num_rewards= 20, grab_range= 2)
hungry_sim()

hungry_sim = ft.add_hungry_birds(hungry_sim, num_hungry_birds= 3, rewards_decay= 0.5, visibility_range= 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3 hungry_sim = ft.Birds(grid_size= 150, num_birds= 3, num_frames= 11, num_rewards= 20, grab_range= 2)
#       4 hungry_sim()
# ----> 6 hungry_sim = ft.add_hungry_birds(hungry_sim, num_hungry_birds= 3, rewards_decay= 0.5, visibility_range= 10)
#
# File ~/L2projects/collaborative-intelligence/random_hungry_followers/rhf_docs/../foraging_toolkit/hungry_birds.py:74, in add_hungry_birds(sim, num_hungry_birds, rewards_decay, visibility_range)
#      72     options = options.head(5)
#      73     chosen_option = options.iloc[np.random.randint(0, 5)]
# ---> 74     new_birds[b][t] = chosen_option.values
#      76 joint_birds = old_birds + new_birds
#      77 ft.update_rewards(sim, joint_birds, start=1, stop=t)
#
# ...

# %%
ft.animate_birds(hungry_sim, plot_rewards=True,
                  width = 600, height = 600, point_size = 10)

# %%
ft.animate_birds(hungry_sim, plot_rewards=True, width = 600,
                  height = 600, point_size = 10,plot_traces=True)
