# %% [markdown]
# # Bird Instance Segmentation Notebook (part 1 of the code pipeline)
#
# This notebook performs **instance segmentation** on video frames, visualizes results, and fine-tunes a pretrained YOLOv8 (or v11) segmentation model. Add in your annotated frames (downloaded from roboflow) and then plug in your video path and run!

# %% [markdown]
# ## 1. Install Dependencies

# %%
# Install required libraries
# !pip install --upgrade --pre ultralytics
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ultralytics in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (8.3.148)
# Requirement already satisfied: numpy>=1.23.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipywidgets) (9.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/yolo/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.2)

# %% [markdown]
# ## 2. Imports & Configuration

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import cv2
from tqdm import tqdm
from ultralytics import YOLO
from tqdm import tqdm
import yaml
import random, shutil
import tempfile

#plotting
import matplotlib.pyplot as plt
from matplotlib.widgets import RectangleSelector
from ipywidgets import interact, IntSlider

# %%
#set up path here for the images downloaded from the manual segmentation
#SRC_ROOT_DIR = Path("/Users/inesaitsahalia/Desktop/labeling_data/yolo/birdLabels.v3i.yolov7pytorch")
SRC_ROOT_DIR = Path("/Users/inesaitsahalia/Desktop/labeling_data/yolo/bird labels.v7i.yolov11")

TARGET_ROOT_DIR = Path("training_images")

# %% [markdown]
# ## 3. Create training and test sets

# %%
#split the dataset into training and validation randomly 

def split_dataset(target_root_dir, images_dir, labels_dir, train_ratio=0.8):
    
    # Debugging: print out what’s in directory
    print(f"Looking for images in: {images_dir.resolve()}")
    print("Exists?", images_dir.exists())
    
    # Create directories if they don't exist
    for dir_name in ['train/images', 'train/labels', 'valid/images', 'valid/labels']:
        Path(target_root_dir /dir_name).mkdir(parents=True, exist_ok=True)
    
    # Get all image files
    image_files = [f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]
    
    # Randomly shuffle the files
    random.shuffle(image_files)
    
    # Calculate split index
    split_idx = int(len(image_files) * train_ratio)
    
    # Split into train and validation sets
    train_files = image_files[:split_idx]
    valid_files = image_files[split_idx:]
    
    # Move files to respective directories
    for files, subset in [(train_files, target_root_dir/'train'), (valid_files, target_root_dir/'valid')]:
        for img_file in files:
            # Move image
            print(f"Moving {img_file} to {subset} / images / {img_file}...")
            shutil.copy2(
                os.path.join(images_dir, img_file),
                os.path.join(subset, 'images', img_file)
            )
            
            # Move corresponding label file
            label_file = os.path.splitext(img_file)[0] + '.txt'
            if os.path.exists(os.path.join(labels_dir, label_file)):
                shutil.copy2(
                    os.path.join(labels_dir, label_file),
                    os.path.join(subset, 'labels', label_file)
                )
    
    # Print statistics
    print(f"Total images: {len(image_files)}")
    print(f"Training set: {len(train_files)}")
    print(f"Validation set: {len(valid_files)}")

# %%
split_dataset(TARGET_ROOT_DIR,
              SRC_ROOT_DIR / 'train' /'images',
              SRC_ROOT_DIR / 'train' / 'labels',
              train_ratio=0.8)
# Out:
# Looking for images in: /Users/inesaitsahalia/Desktop/labeling_data/yolo/bird labels.v7i.yolov
# Moving thermal_12_17_mov-0769_jpg.rf.91091c00b2322ee16d1336c587212090.jpg to training_images/train / images / thermal_12_17_mov-0769_jpg.rf.91091c00b2322ee16d1336c587212090.jpg...
# Moving thermal_12_17_mov-0271_jpg.rf.2643b3ed5ab7420e098418af67da440b.jpg to training_images/train / images / thermal_12_17_mov-0271_jpg.rf.2643b3ed5ab7420e098418af67da440b.jpg...
# Moving thermal_12_17_mov-0285_jpg.rf.8561b391482d2c61f1c68dbd7060a931.jpg to training_images/train / images / thermal_12_17_mov-0285_jpg.rf.8561b391482d2c61f1c68dbd7060a931.jpg...
# Moving thermal_12_17_mov-0130_jpg.rf.5d575f569b332ea6166998c3629fa6e1.jpg to training_images/train / images / thermal_12_17_mov-0130_jpg.rf.5d575f569b332ea6166998c3629fa6e1.jpg...
# Moving thermal_15_20_mov-15772_jpg.rf.28db46793ef5df653753ffc269556146.jpg to training_images/train / images / thermal_15_20_mov-15772_jpg.rf.28db46793ef5df653753ffc269556146.jpg...
# Moving thermal_15_20_mov-0096_jpg.rf.cc6c6cb5cf22ca967d122cb9b2b7a815.jpg to training_images/train / images / thermal_15_20_mov-0096_jpg.rf.cc6c6cb5cf22ca967d122cb9b2b7a815.jpg...
# Moving thermal_12_17_mov-0025_jpg.rf.b9efe5461c01a12fd9fd53ce74248220.jpg to training_images/train / images / thermal_12_17_mov-0025_jpg.rf.b9efe5461c01a12fd9fd53ce74248220.jpg...
# Moving thermal_12_17_mov-0225_jpg.rf.48de5d78a87c3db612ccf2c344443b88.jpg to training_images/train / images / thermal_12_17_mov-0225_jpg.rf.48de5d78a87c3db612ccf2c344443b88.jpg...
# Moving thermal_15_20_mov-3627_jpg.rf.7179bcaf8af3edd922fc8096f5333ff7.jpg to training_images/train / images / thermal_15_20_mov-3627_jpg.rf.7179bcaf8af3edd922fc8096f5333ff7.jpg...
# Moving thermal_12_17_mov-0259_jpg.rf.e36005bce22d62f839ccda65a2915c33.jpg to training_images/train / images / thermal_12_17_mov-0259_jpg.rf.e36005bce22d62f839ccda65a2915c33.jpg...
# Moving thermal_12_17_mov-0262_jpg.rf.38a88e9331197ff6f30535e444610d83.jpg to training_images/train / images / thermal_12_17_mov-0262_jpg.rf.38a88e9331197ff6f30535e444610d83.jpg...
# ...
# Moving thermal_12_17_mov-0001_jpg.rf.f27a67fa68de494c9e54f8b762d7b636.jpg to training_images/valid / images / thermal_12_17_mov-0001_jpg.rf.f27a67fa68de494c9e54f8b762d7b636.jpg...
# Moving thermal_12_17_mov-0640_jpg.rf.06e244ca61d02775457bbe0ac5f4dc29.jpg to training_images/valid / images / thermal_12_17_mov-0640_jpg.rf.06e244ca61d02775457bbe0ac5f4dc29.jpg...
# Moving thermal_12_17_mov-0012_jpg.rf.c41c762056d8a9519a478e8da8aeed08.jpg to training_images/valid / images / thermal_12_17_mov-0012_jpg.rf.c41c762056d8a9519a478e8da8aeed08.jpg...
# Moving rgb_cranes_mp4-0161_jpg.rf.e37cba4c6efedcd6aae9477a4fd9d422.jpg to training_images/valid / images / rgb_cranes_mp4-0161_jpg.rf.e37cba4c6efedcd6aae9477a4fd9d422.jpg...
# Moving thermal_15_20_mov-6769_jpg.rf.f008f4f656e0f15c76fbe46cae854ef8.jpg to training_images/valid / images / thermal_15_20_mov-6769_jpg.rf.f008f4f656e0f15c76fbe46cae854ef8.jpg...
# Moving thermal_12_17_mov-0085_jpg.rf.a06b8a1a702b72877629c3b3a2db87fc.jpg to training_images/valid / images / thermal_12_17_mov-0085_jpg.rf.a06b8a1a702b72877629c3b3a2db87fc.jpg...
# Moving rgb_cranes_mp4-0163_jpg.rf.c5bf0f399d37eeeffc624acc0af04616.jpg to training_images/valid / images / rgb_cranes_mp4-0163_jpg.rf.c5bf0f399d37eeeffc624acc0af04616.jpg...
# Moving thermal_12_17_mov-0267_jpg.rf.112821b9ba2abec90a56e0c2f6bb374c.jpg to training_images/valid / images / thermal_12_17_mov-0267_jpg.rf.112821b9ba2abec90a56e0c2f6bb374c.jpg...
# Moving rgb_cranes_mp4-0805_jpg.rf.be0236bd56e2513ba9f586de21ba1fae.jpg to training_images/valid / images / rgb_cranes_mp4-0805_jpg.rf.be0236bd56e2513ba9f586de21ba1fae.jpg...
# Moving thermal_12_17_mov-0036_jpg.rf.5155b0db03c3cfd366f1f24e5fffde17.jpg to training_images/valid / images / thermal_12_17_mov-0036_jpg.rf.5155b0db03c3cfd366f1f24e5fffde17.jpg...
# Moving thermal_12_17_mov-0055_jpg.rf.1014710f9ddaa0f85d2d535305d96baf.jpg to training_images/valid / images / thermal_12_17_mov-0055_jpg.rf.1014710f9ddaa0f85d2d535305d96baf.jpg...
# Moving thermal_12_17_mov-0544_jpg.rf.df3d964f2499f1ae1cc5b12e859fdb86.jpg to training_images/valid / images / thermal_12_17_mov-0544_jpg.rf.df3d964f2499f1ae1cc5b12e859fdb86.jpg...
# Moving thermal_12_17_mov-0015_jpg.rf.59744a671e0a1b1f49d8c0df713fc0fb.jpg to training_images/valid / images / thermal_12_17_mov-0015_jpg.rf.59744a671e0a1b1f49d8c0df713fc0fb.jpg...
# Moving thermal_12_17_mov-0049_jpg.rf.35d88d8f11b1fe9d9f3890ba86544297.jpg to training_images/valid / images / thermal_12_17_mov-0049_jpg.rf.35d88d8f11b1fe9d9f3890ba86544297.jpg...
# Moving thermal_12_17_mov-0057_jpg.rf.08b5d2a75d143c9a87bc3ab2c1aee728.jpg to training_images/valid / images / thermal_12_17_mov-0057_jpg.rf.08b5d2a75d143c9a87bc3ab2c1aee728.jpg...
# Moving rgb_cranes_mp4-0274_jpg.rf.dc9d0587fbeba4af2c70267a79572b9c.jpg to training_images/valid / images / rgb_cranes_mp4-0274_jpg.rf.dc9d0587fbeba4af2c70267a79572b9c.jpg...
# Moving thermal_12_17_mov-0261_jpg.rf.36d037ceb577ba79ec13889689e61130.jpg to training_images/valid / images / thermal_12_17_mov-0261_jpg.rf.36d037ceb577ba79ec13889689e61130.jpg...
# Moving thermal_12_17_mov-0043_jpg.rf.1da5d72d15449f865284edf14a60a395.jpg to training_images/valid / images / thermal_12_17_mov-0043_jpg.rf.1da5d72d15449f865284edf14a60a395.jpg...
# Moving thermal_12_17_mov-0076_jpg.rf.fc4025af003bbf56b9ac95db20e7a142.jpg to training_images/valid / images / thermal_12_17_mov-0076_jpg.rf.fc4025af003bbf56b9ac95db20e7a142.jpg...
# Moving thermal_12_17_mov-0073_jpg.rf.33d7025d813c143ba22249d8551085cc.jpg to training_images/valid / images / thermal_12_17_mov-0073_jpg.rf.33d7025d813c143ba22249d8551085cc.jpg...
# Moving thermal_15_20_mov-9502_jpg.rf.3b47253735a63e719e4ee53424c547cf.jpg to training_images/valid / images / thermal_15_20_mov-9502_jpg.rf.3b47253735a63e719e4ee53424c547cf.jpg...
# Moving thermal_12_17_mov-0265_jpg.rf.fcbe9ff5f9921adc2347f2ba6f276be8.jpg to training_images/valid / images / thermal_12_17_mov-0265_jpg.rf.fcbe9ff5f9921adc2347f2ba6f276be8.jpg...
# Moving thermal_12_17_mov-0325_jpg.rf.cad43bc88a86f7ca52aa4d6cf5e82465.jpg to training_images/valid / images / thermal_12_17_mov-0325_jpg.rf.cad43bc88a86f7ca52aa4d6cf5e82465.jpg...
# Moving thermal_12_17_mov-0042_jpg.rf.6b0f533a241c29f83f7bd5e2d8988319.jpg to training_images/valid / images / thermal_12_17_mov-0042_jpg.rf.6b0f533a241c29f83f7bd5e2d8988319.jpg...
# Moving rgb_cranes_mp4-0191_jpg.rf.c3e2207bcbe4b89f03d8080970b01abe.jpg to training_images/valid / images / rgb_cranes_mp4-0191_jpg.rf.c3e2207bcbe4b89f03d8080970b01abe.jpg...
# Moving thermal_12_17_mov-0100_jpg.rf.9e3718df2d485bb2010c5e17c8a7b87e.jpg to training_images/valid / images / thermal_12_17_mov-0100_jpg.rf.9e3718df2d485bb2010c5e17c8a7b87e.jpg...
# Moving thermal_15_20_mov-0498_jpg.rf.b307319256fd11b6c1f641eba012a4ab.jpg to training_images/valid / images / thermal_15_20_mov-0498_jpg.rf.b307319256fd11b6c1f641eba012a4ab.jpg...
# Moving thermal_15_20_mov-14547_jpg.rf.a93a72bb50cacd56ed08de8d0e6cfb45.jpg to training_images/valid / images / thermal_15_20_mov-14547_jpg.rf.a93a72bb50cacd56ed08de8d0e6cfb45.jpg...
# Moving thermal_12_17_mov-0006_jpg.rf.55dc694728a82fc76f3baf8a63e1e3b4.jpg to training_images/valid / images / thermal_12_17_mov-0006_jpg.rf.55dc694728a82fc76f3baf8a63e1e3b4.jpg...
# Moving thermal_12_17_mov-0252_jpg.rf.451c3c061f6b6afbfdb1a21e23ab26dc.jpg to training_images/valid / images / thermal_12_17_mov-0252_jpg.rf.451c3c061f6b6afbfdb1a21e23ab26dc.jpg...
# Moving thermal_12_17_mov-0045_jpg.rf.05f0156a71e2de88aefbd460b8ff3fbc.jpg to training_images/valid / images / thermal_12_17_mov-0045_jpg.rf.05f0156a71e2de88aefbd460b8ff3fbc.jpg...
# Moving thermal_12_17_mov-0013_jpg.rf.a946ad56c159c4275292a5789c21ef49.jpg to training_images/valid / images / thermal_12_17_mov-0013_jpg.rf.a946ad56c159c4275292a5789c21ef49.jpg...
# Moving thermal_12_17_mov-0093_jpg.rf.bca0f0507b8b6bee93275dafaca3d135.jpg to training_images/valid / images / thermal_12_17_mov-0093_jpg.rf.bca0f0507b8b6bee93275dafaca3d135.jpg...
# Moving thermal_12_17_mov-0027_jpg.rf.c10c85797369cc33035a7db75670f7a3.jpg to training_images/valid / images / thermal_12_17_mov-0027_jpg.rf.c10c85797369cc33035a7db75670f7a3.jpg...
# Moving thermal_12_17_mov-0151_jpg.rf.3008462587f9ed8fe308301ba1a7c148.jpg to training_images/valid / images / thermal_12_17_mov-0151_jpg.rf.3008462587f9ed8fe308301ba1a7c148.jpg...
# Moving thermal_12_17_mov-0679_jpg.rf.23d853c35b20d0469b2993b379168c00.jpg to training_images/valid / images / thermal_12_17_mov-0679_jpg.rf.23d853c35b20d0469b2993b379168c00.jpg...
# Moving thermal_12_17_mov-0028_jpg.rf.07b69e5e175c54210dddd34ed5c5236e.jpg to training_images/valid / images / thermal_12_17_mov-0028_jpg.rf.07b69e5e175c54210dddd34ed5c5236e.jpg...
# Moving thermal_15_20_mov-0841_jpg.rf.77058540c725ac73533f23b48107d4a5.jpg to training_images/valid / images / thermal_15_20_mov-0841_jpg.rf.77058540c725ac73533f23b48107d4a5.jpg...
# Moving thermal_12_17_mov-0057_jpg.rf.50cc2bf332c26228c5136036234b83d1.jpg to training_images/valid / images / thermal_12_17_mov-0057_jpg.rf.50cc2bf332c26228c5136036234b83d1.jpg...
# Moving thermal_15_20_mov-10869_jpg.rf.e4d24b046e16dd03b197e4458a5e0ff2.jpg to training_images/valid / images / thermal_15_20_mov-10869_jpg.rf.e4d24b046e16dd03b197e4458a5e0ff2.jpg...
# Moving thermal_12_17_mov-0082_jpg.rf.6d20a9e76d5c7bb76e6a7d7a723cf11c.jpg to training_images/valid / images / thermal_12_17_mov-0082_jpg.rf.6d20a9e76d5c7bb76e6a7d7a723cf11c.jpg...
# Moving thermal_15_20_mov-15772_jpg.rf.5f0302679b1baa5a2f54dff17e9373da.jpg to training_images/valid / images / thermal_15_20_mov-15772_jpg.rf.5f0302679b1baa5a2f54dff17e9373da.jpg...
# Moving thermal_12_17_mov-0070_jpg.rf.6d3676b7f405eee60f4f133b4bf00ced.jpg to training_images/valid / images / thermal_12_17_mov-0070_jpg.rf.6d3676b7f405eee60f4f133b4bf00ced.jpg...
# Moving thermal_15_20_mov-16662_jpg.rf.4222f177049434cc1e9c6c63ecc0c421.jpg to training_images/valid / images / thermal_15_20_mov-16662_jpg.rf.4222f177049434cc1e9c6c63ecc0c421.jpg...
# Moving thermal_12_17_mov-0054_jpg.rf.a643f37bf71937ffd7001a88e8ca4518.jpg to training_images/valid / images / thermal_12_17_mov-0054_jpg.rf.a643f37bf71937ffd7001a88e8ca4518.jpg...
# Moving thermal_12_17_mov-0247_jpg.rf.a3c52eb56d49ab7977d5d4e4a6ca9c67.jpg to training_images/valid / images / thermal_12_17_mov-0247_jpg.rf.a3c52eb56d49ab7977d5d4e4a6ca9c67.jpg...
# Moving thermal_12_17_mov-0064_jpg.rf.567ad819765673c2fceaf20461328179.jpg to training_images/valid / images / thermal_12_17_mov-0064_jpg.rf.567ad819765673c2fceaf20461328179.jpg...
# Moving thermal_12_17_mov-0717_jpg.rf.77d4bd43c4f108e6e4754e93a2568b9f.jpg to training_images/valid / images / thermal_12_17_mov-0717_jpg.rf.77d4bd43c4f108e6e4754e93a2568b9f.jpg...
# Moving thermal_15_20_mov-5494_jpg.rf.9b4879b0cd4d1b9bb7c61ec5ad1ec21f.jpg to training_images/valid / images / thermal_15_20_mov-5494_jpg.rf.9b4879b0cd4d1b9bb7c61ec5ad1ec21f.jpg...
# Moving thermal_12_17_mov-0769_jpg.rf.122787c80a7c3778d55ae67dcc808a92.jpg to training_images/valid / images / thermal_12_17_mov-0769_jpg.rf.122787c80a7c3778d55ae67dcc808a92.jpg...
# Moving thermal_12_17_mov-0054_jpg.rf.d7cd7548a3edbecb1d995415307ef036.jpg to training_images/valid / images / thermal_12_17_mov-0054_jpg.rf.d7cd7548a3edbecb1d995415307ef036.jpg...
# Moving thermal_12_17_mov-0247_jpg.rf.4f9ba8466ed7852c003b126c2226a1fe.jpg to training_images/valid / images / thermal_12_17_mov-0247_jpg.rf.4f9ba8466ed7852c003b126c2226a1fe.jpg...
# Moving thermal_12_17_mov-0066_jpg.rf.b03d8f553fd3f311d581577deef746fb.jpg to training_images/valid / images / thermal_12_17_mov-0066_jpg.rf.b03d8f553fd3f311d581577deef746fb.jpg...
# Moving thermal_12_17_mov-0130_jpg.rf.45fc7a9cc1524e0c43a3b22cd018e50e.jpg to training_images/valid / images / thermal_12_17_mov-0130_jpg.rf.45fc7a9cc1524e0c43a3b22cd018e50e.jpg...
# Moving thermal_12_17_mov-0223_jpg.rf.180cfb0b01e4f56f3bfebc21fbd18856.jpg to training_images/valid / images / thermal_12_17_mov-0223_jpg.rf.180cfb0b01e4f56f3bfebc21fbd18856.jpg...
# Moving thermal_12_17_mov-0579_jpg.rf.596444ed819d3e5df55159589e71860b.jpg to training_images/valid / images / thermal_12_17_mov-0579_jpg.rf.596444ed819d3e5df55159589e71860b.jpg...
# Moving thermal_15_20_mov-14434_jpg.rf.b1ee68fb757a647d67fa81504cff2cd9.jpg to training_images/valid / images / thermal_15_20_mov-14434_jpg.rf.b1ee68fb757a647d67fa81504cff2cd9.jpg...
# Moving thermal_12_17_mov-0081_jpg.rf.7f781e8e34523c11a4d5382ca5838b04.jpg to training_images/valid / images / thermal_12_17_mov-0081_jpg.rf.7f781e8e34523c11a4d5382ca5838b04.jpg...
# Moving rgb_cranes_mp4-0032_jpg.rf.5fcbf2f47419a15290af2afdf1e2e0db.jpg to training_images/valid / images / rgb_cranes_mp4-0032_jpg.rf.5fcbf2f47419a15290af2afdf1e2e0db.jpg...
# Moving thermal_12_17_mov-0096_jpg.rf.aaab33f2d1738d970806993c0607aeb4.jpg to training_images/valid / images / thermal_12_17_mov-0096_jpg.rf.aaab33f2d1738d970806993c0607aeb4.jpg...
# Total images: 472
# Training set: 377
# Validation set: 95

# %% [markdown]
# ## 4. Load Pretrained Segmentation Model

# %%
# Load a pretrained segmentation model
# model = YOLO('yolov8n-seg.pt')  # nano version
model = YOLO('yolo11n-seg.pt')  # nano version
# Out:
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# #### create the data file for the model using the path you want: Note that if the roboflow export is in yolo11 format, you can skip this step, as it is generated automatically.

# %%
# # Write a simple dataset YAML for YOLO
# def create_data_yaml(train_dir, val_dir, nc, names, save_path="data.yaml"):
#     data = {
#         'train': str(train_dir),
#         'val': str(val_dir),
#         'nc': nc,
#         'names': names
#     }
#     save_path = Path(save_path)
#     save_path.parent.mkdir(parents=True, exist_ok=True)  # ensure folder exists
#     with open(save_path, 'w') as f:
#         yaml.dump(data, f)
#     print(f"✓ Wrote {save_path.resolve()}")

# %%
# create_data_yaml(
#     train_dir=SRC_ROOT_DIR / 'train' / 'images',
#     val_dir=SRC_ROOT_DIR / 'valid' / 'images',
#     nc=1,
#     names=['bird'],
#     save_path=TARGET_ROOT_DIR / 'data.yaml'
# )

# %% [markdown]
# ## 5. Train the model so it doesn't suck

# %%
# Train the model
results = model.train(
    data=SRC_ROOT_DIR / 'data.yaml',
    epochs=50,
    imgsz=(320, 240),
    batch=4,
    device='cpu'  # use 'cpu' if no GPU
)

print('Training complete! :D')
# Out:
# Ultralytics 8.3.148 🚀 Python-3.11.11 torch-2.7.0 CPU (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/inesaitsahalia/Desktop/labeling_data/yolo/bird labels.v7i.yolov11/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=(320, 240), int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train8, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/segment/train8, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    683635  ultralytics.nn.modules.head.Segment          [1, 32, 64, [64, 128, 256]]
# YOLO11n-seg summary: 203 layers, 2,842,803 parameters, 2,842,787 gradients, 10.4 GFLOPs
#
# Transferred 510/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# WARNING ⚠️ updating to 'imgsz=320'. 'train' and 'val' imgsz must be an integer, while 'predict' and 'export' imgsz may be a [h, w] list or an integer, i.e. 'yolo export imgsz=640,480' or 'yolo export imgsz=640'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1383.1±293.1 MB/s, size: 29.8 KB)
# train: Scanning /Users/inesaitsahalia/Desktop/labeling_data/yolo/bird labels.v7i.yolov11/train/labels... 472 images, 3 backgrounds, 0 corrupt: 100%|██████████| 472/472 [00:00<00:00, 4401.02it/s]
# train: New cache created: /Users/inesaitsahalia/Desktop/labeling_data/yolo/bird labels.v7i.yolov11/train/labels.cache
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 95.1±48.0 MB/s, size: 32.4 KB)
# val: Scanning /Users/inesaitsahalia/Desktop/labeling_data/yolo/bird labels.v7i.yolov11/valid/labels... 41 images, 18 backgrounds, 0 corrupt: 100%|██████████| 41/41 [00:00<00:00, 4846.31it/s]
# val: New cache created: /Users/inesaitsahalia/Desktop/labeling_data/yolo/bird labels.v7i.yolov11/valid/labels.cache
# Plotting labels to runs/segment/train8/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 90 weight(decay=0.0), 101 weight(decay=0.0005), 100 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 0 dataloader workers
# Logging results to runs/segment/train8
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: divide by zero encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: overflow encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: invalid value encountered in matmul
#   xy = xy @ M.T  # transform
#        1/50         0G      2.383      3.198       2.45     0.9193         43        320: 100%|██████████| 118/118 [00:56<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  3.71it/s]
#                    all         41        389    0.00717      0.226     0.0456     0.0171    0.00676      0.213      0.027    0.00858
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: divide by zero encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: overflow encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: invalid value encountered in matmul
#   xy = xy @ M.T  # transform
#        2/50         0G      2.234      2.977      1.415     0.8907         18        320: 100%|██████████| 118/118 [00:55<00:00,  2.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.48it/s]
#                    all         41        389      0.652      0.216      0.212     0.0954      0.376      0.141      0.109     0.0372
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: divide by zero encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: overflow encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: invalid value encountered in matmul
#   xy = xy @ M.T  # transform
#        3/50         0G      2.283       2.88      1.297     0.8925         43        320: 100%|██████████| 118/118 [00:55<00:00,  2.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.18it/s]
#                    all         41        389       0.63      0.219      0.223     0.0982      0.372      0.162      0.137     0.0527
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: divide by zero encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: overflow encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: invalid value encountered in matmul
#   xy = xy @ M.T  # transform
#        4/50         0G      2.181      2.846      1.188      0.885         39        320: 100%|██████████| 118/118 [00:56<00:00,  2.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.63it/s]
#                    all         41        389      0.696      0.234      0.249      0.106       0.41      0.172      0.143     0.0475
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: divide by zero encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: overflow encountered in matmul
#   xy = xy @ M.T  # transform
# /opt/anaconda3/envs/yolo/lib/python3.11/site-packages/ultralytics/data/augment.py:1240: RuntimeWarning: invalid value encountered in matmul
#   xy = xy @ M.T  # transform
#        5/50         0G      2.267      2.812      1.129     0.8818         40        320:  90%|████████▉ | 106/118 [00:50<00:05,  2.04it/s]

# %% [markdown]
# ## test the model on other videos

# %%
# trained model path
model_path = 'runs/segment/train8/weights/best.pt'
#model = YOLO('yolo11n-seg.pt')  # nano version, use this if the 
model = YOLO(model_path)

# %%
#chek to make sure you're where you want to be 

# Print the current working directory
print(f"Current working directory: {os.getcwd()}")

# List files in the videos directory
video_dir = "videos"
if os.path.exists(video_dir):
    print(f"Files in {video_dir}:")
    for file in os.listdir(video_dir):
        print(f"  - {file}")
else:
    print(f"Directory {video_dir} does not exist!")

# %%
#load in the video you want 
VIDEO_PATH = "videos/thermal_15_20.mp4"   # for now still testing on the one video 

# 1) Check it really exists
if not Path(VIDEO_PATH).is_file():
    raise FileNotFoundError(f"Video file not found at: {VIDEO_PATH!r}")

# 2) Try opening and verify
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise IOError(f"OpenCV failed to open video file: {VIDEO_PATH!r}")
# if you get here, it’s safe to proceed
cap.release()

FRAMES_DIR = "frames"
ANNOTATED_DIR = "annotations"
os.makedirs(FRAMES_DIR, exist_ok=True)
os.makedirs(ANNOTATED_DIR, exist_ok=True)

# %% [markdown]
# ### split the videos into frames

# %%
#turn the video into images you'll be able to predict the model on later

def video_to_frames(video_path, out_dir, prefix="frame"):
    """
    Extracts frames from a video and saves them as .jpg.
    """
    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    idx = 0
    with tqdm(total=total, desc="Extracting frames") as pbar:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            fname = f"{prefix}_{idx:06d}.jpg"
            cv2.imwrite(os.path.join(out_dir, fname), frame)
            idx += 1
            pbar.update(1)
    cap.release()
    print(f"Saved {idx} frames to {out_dir}")

# Run this to extract frames
video_to_frames(VIDEO_PATH, FRAMES_DIR)

# %%
# give the path to hat you want to test on 
inference_source = FRAMES_DIR # new video to test on
results = model(inference_source, stream = True)


# Display not every frame 
step = 1000
for i, result in enumerate(results):
    if i % step != 0:
        continue
    
    result.show()

# %% [markdown]
# ## try to align the frames of the rgb to the thermal
#
# test version for a single image

# %%
# --- Load images ---
rgb_img = cv2.imread(TARGET_ROOT_DIR/'rgb_trial.jpeg')
thermal_img = cv2.imread(TARGET_ROOT_DIR/'thermal_trial.png')

# Resize to the same shape for ECC (optional: crop instead if needed)
rgb_crop = cv2.resize(rgb_img, (640, 480))
thermal_crop = cv2.resize(thermal_img, (640, 480))



def select_points(img, window_name, min_points: int = 4):
    """
    Let the user click corresponding points in a window.
    ▸ Left‑click  to add a point  (green dot).
    ▸ Enter/Return or Esc closes the window *after* min_points clicks.
    Returns
    -------
    np.ndarray[float32]  shape = (N, 2)
    """
    points = []
    clone = img.copy()

    def click_event(event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN:
            points.append((x, y))
            cv2.circle(clone, (x, y), 5, (0, 255, 0), -1)
            cv2.imshow(window_name, clone)

    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
    cv2.setMouseCallback(window_name, click_event)
    cv2.imshow(window_name, clone)

    print(f"🖱  Click at least {min_points} points, "
          "then press Esc to continue…")

    while True:
        key = cv2.waitKey(1) & 0xFF
        # 13 = Enter/Return, 27 = Esc
        if key in (13, 27):
            if len(points) >= min_points:
                break
            else:
                print(f" Need {min_points} points; you have {len(points)}.")
    cv2.destroyWindow(window_name)
    return np.array(points, dtype=np.float32)


print("Select points in RGB image")
pts_rgb = select_points(rgb_crop, "RGB - select points")

print("Select corresponding points in Thermal image")
pts_thm = select_points(thermal_crop, "Thermal - select points")

assert len(pts_rgb) >= 4 and len(pts_thm) == len(pts_rgb), "Need at least 4 matching points"

# --- Compute Homography & Warp ---
H, _ = cv2.findHomography(pts_thm, pts_rgb, cv2.RANSAC)
aligned_thm = cv2.warpPerspective(thermal_crop, H, (rgb_crop.shape[1], rgb_crop.shape[0]))

# --- Overlay ---
alpha = 0.5
overlay = cv2.addWeighted(rgb_crop, alpha, aligned_thm, 1 - alpha, 0)

# Convert BGR to RGB for display
rgb_crop = cv2.cvtColor(rgb_crop, cv2.COLOR_BGR2RGB)
aligned_thm = cv2.cvtColor(aligned_thm, cv2.COLOR_BGR2RGB)
overlay = cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB)

# --- Plot ---
fig, axs = plt.subplots(1, 3, figsize=(18, 6))
axs[0].imshow(rgb_crop)
axs[0].set_title('RGB Cropped')
axs[1].imshow(aligned_thm)
axs[1].set_title('Aligned Thermal')
axs[2].imshow(overlay)
axs[2].set_title('Overlay')
for ax in axs: ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### modify the rgb FOV to fit the crop of the thermal (roughly)
# use file for the gui (stored separately)

# %%
import subprocess

vid_in = "videos/rgb_518152_A.mp4"
vid_out = "videos/rgb_518152_A_adjusted.mp4"

# Run the external script
subprocess.run([
    "python", "rotate_crop_gui.py",
    "--input", vid_in,
    "--output", vid_out
])

# %% [markdown]
# ### align spatially

# %%
# --- Configuration ---
RGB_PATH = "videos/rgb_518152_A_adjusted.mp4"
THERMAL_PATH = "videos/thermal_12_17.mov"
OUTPUT_DIR = "aligned_frames"

RECALIBRATION_FRAMES = [1]  # manual alignment trigger frames (good for checking in longer vids)
FRAME_SIZE = (640, 480)     # Standard frame size for processing (idk this was the default in the 
OVERLAY_ALPHA = 0.3
MAX_FRAMES = 300            # Set to None to process the full video

# --- Utility: Interactive point selection ---
def select_points(img, window_name):
    points = []

    def click_event(event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN:
            points.append((x, y))
            cv2.circle(img, (x, y), 5, (0, 255, 0), -1)
            cv2.imshow(window_name, img)

    cv2.imshow(window_name, img)
    cv2.setMouseCallback(window_name, click_event)
    print("Click any 4+ corresponding points in the image in the **same** order, then press any key to continue :)")
    cv2.waitKey(0)
    cv2.destroyWindow(window_name)
    return np.array(points, dtype=np.float32)

# --- Load videos ---
rgb_video = cv2.VideoCapture(RGB_PATH)
thermal_video = cv2.VideoCapture(THERMAL_PATH)

if not rgb_video.isOpened() or not thermal_video.isOpened():
    raise IOError("yoinks! Could not open one or both video files.")

# --- Get video info ---
frame_count = int(min(rgb_video.get(cv2.CAP_PROP_FRAME_COUNT), thermal_video.get(cv2.CAP_PROP_FRAME_COUNT)))
fps = int(rgb_video.get(cv2.CAP_PROP_FPS))

# --- Limit frame count if MAX_FRAMES is set ---
if MAX_FRAMES is not None:
    frame_count = min(frame_count, MAX_FRAMES)

# --- Setup output ---
os.makedirs(OUTPUT_DIR, exist_ok=True)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_aligned = cv2.VideoWriter('aligned_thermal.mp4', fourcc, fps, FRAME_SIZE)
out_aligned_rgb = cv2.VideoWriter('aligned_rgb.mp4', fourcc, fps, FRAME_SIZE)
out_overlay = cv2.VideoWriter('overlay_video.mp4', fourcc, fps, FRAME_SIZE)

current_H = None

for frame_idx in tqdm(range(frame_count), desc="Processing video"):
    ret_rgb, frame_rgb = rgb_video.read()
    ret_thm, frame_thm = thermal_video.read()
    if not (ret_rgb and ret_thm):
        break

    frame_rgb = cv2.resize(frame_rgb, FRAME_SIZE)
    frame_thm = cv2.resize(frame_thm, FRAME_SIZE)

    # --- Manual alignment setup ---
    if frame_idx in RECALIBRATION_FRAMES:
        print(f"\n📌 Frame {frame_idx}: Manual alignment")
        print("➡ Select corresponding points on RGB frame...")
        pts_rgb = select_points(frame_rgb.copy(), f"RGB @ {frame_idx}")
        print("➡ Select corresponding points on Thermal frame...")
        pts_thm = select_points(frame_thm.copy(), f"Thermal @ {frame_idx}")
        if pts_rgb.shape[0] >= 4 and pts_rgb.shape == pts_thm.shape:
            current_H, _ = cv2.findHomography(pts_thm, pts_rgb, cv2.RANSAC)
            print("✔ Homography updated.")
        else:
            print("yikes! Invalid point selection. Skipping frame.")
            continue

    if current_H is None:
        print(f"⚠ Skipping frame {frame_idx}: No valid homography available yet.")
        continue

    # --- Align thermal frame ---
    aligned_thm = cv2.warpPerspective(frame_thm, current_H, FRAME_SIZE)

    # --- Match channels if needed ---
    if len(aligned_thm.shape) < 3 or aligned_thm.shape[2] != 3:
        aligned_thm = cv2.cvtColor(aligned_thm, cv2.COLOR_GRAY2BGR)

    # --- Create overlay ---
    overlay = cv2.addWeighted(frame_rgb, OVERLAY_ALPHA, aligned_thm, 1 - OVERLAY_ALPHA, 0)

    # --- Save frames ---
    aligned_path = os.path.join(OUTPUT_DIR, f"aligned_{frame_idx:05d}.png")
    overlay_path = os.path.join(OUTPUT_DIR, f"overlay_{frame_idx:05d}.png")
    cv2.imwrite(aligned_path, aligned_thm)
    cv2.imwrite(overlay_path, overlay)

    # --- Write video frames ---
    out_aligned.write(aligned_thm)
    out_aligned_rgb.write(frame_rgb)
    out_overlay.write(overlay)

# --- Cleanup ---
rgb_video.release()
thermal_video.release()
out_aligned.release()
out_aligned_rgb.release()
out_overlay.release()

print("\n✅ Done! Saved:")
print("   ▶ Aligned thermal video → 'aligned_thermal.mp4'")
print("   ▶ Aligned RGB video → 'aligned_rgb.mp4'")
print("   ▶ RGB-thermal overlay video → 'overlay_video.mp4'")
print(f"   ▶ Aligned frames saved in → '{OUTPUT_DIR}/'")

# %% [markdown]
# ### align temporally

# %%
#turn the video into images you'll be able to predict the model on later

def video_to_frames(video_path, out_dir, prefix="frame"):
    """
    Extracts frames from a video and saves them as .jpg.
    """
    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    idx = 0
    with tqdm(total=total, desc="Extracting frames") as pbar:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            fname = f"{prefix}_{idx:06d}.jpg"
            cv2.imwrite(os.path.join(out_dir, fname), frame)
            idx += 1
            pbar.update(1)
    cap.release()
    print(f"Saved {idx} frames to {out_dir}")

# %%
VIDEO_PATH_RGB = 'processed_videos/aligned_rgb.mp4'
FRAMES_DIR_RGB = 'processed_videos/RGB_frames'
# Run this to extract frames from the adjusted and aligned videos 
video_to_frames(VIDEO_PATH_RGB, FRAMES_DIR_RGB)

VIDEO_PATH_TH = 'processed_videos/aligned_thermal.mp4'
FRAMES_DIR_TH = 'processed_videos/THM_frames'
# Run this to extract frames from the adjusted and aligned videos 
video_to_frames(VIDEO_PATH_TH, FRAMES_DIR_TH)

# %% [markdown]
# ## run the tracking on the modified version

# %%
# path to the new aligned frame folders 
inference_source = 'processed_videos/THM_frames'  
results = model(inference_source)

# Display every so often frame only
step = 50
for i, result in enumerate(results):
    if i % step != 0:
        continue
    
    rendered_img = result.plot()  # Renders image with masks and boxes
    plt.figure(figsize=(10, 10))
    plt.imshow(rendered_img)
    plt.title(f'Frame {i}')
    plt.axis('off')
    plt.show()
